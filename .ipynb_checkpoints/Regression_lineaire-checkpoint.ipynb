# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df_1 = pd.read_csv('../student_habits_performance.csv')
df_1.head(5)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df = df_1.drop(columns=['student_id', 'exam_score'])

# %%
df_numeric = df.select_dtypes(exclude='object')
df_object = df.select_dtypes(include='object')

# %%
df_numeric = df_numeric.assign(**{col + "_carre": df_numeric[col]**2 for col in df_numeric.columns})
df_numeric.head(5)
# Out:
#    age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23                  0.0                 1.2            1.1
# 1   20                  6.9                 2.8            2.3
# 2   21                  1.4                 3.1            1.3
# 3   23                  1.0                 3.9            1.0
# 4   19                  5.0                 4.4            0.5
#
#    attendance_percentage  sleep_hours  exercise_frequency  \
# 0                   85.0          8.0                   6
# 1                   97.3          4.6                   6
# 2                   94.8          8.0                   1
# 3                   71.0          9.2                   4
# 4                   90.9          4.9                   3
#
#    mental_health_rating  age_carre  study_hours_per_day_carre  \
# 0                     8        529                       0.00
# 1                     8        400                      47.61
# ...

# %%
df_final = pd.concat([df_numeric , df_object] , axis=1 )

# %%
# Vérification du type de chaque variable
df_final.dtypes
# Out:
# age                                int64
# study_hours_per_day              float64
# social_media_hours               float64
# netflix_hours                    float64
# attendance_percentage            float64
# sleep_hours                      float64
# exercise_frequency                 int64
# mental_health_rating               int64
# age_carre                          int64
# study_hours_per_day_carre        float64
# social_media_hours_carre         float64
# netflix_hours_carre              float64
# attendance_percentage_carre      float64
# sleep_hours_carre                float64
# exercise_frequency_carre           int64
# mental_health_rating_carre         int64
# gender                            object
# part_time_job                     object
# diet_quality                      object
# parental_education_level          object
# internet_quality                  object
# extracurricular_participation     object
# dtype: object

# %%
# Vérification des valeurs manquantes

df_manque = df_final.isnull().sum()
df_manque[df_manque > 0]
# Out:
# parental_education_level    91
# dtype: int64

# %%
# Imputation de la variable parental_education_level par le mode
df_final['parental_education_level'] = df_final['parental_education_level'].fillna(df_final['parental_education_level'].mode()[0])

# %%
df_final.isnull().sum()
# Out:
# age                              0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# attendance_percentage            0
# sleep_hours                      0
# exercise_frequency               0
# mental_health_rating             0
# age_carre                        0
# study_hours_per_day_carre        0
# social_media_hours_carre         0
# netflix_hours_carre              0
# attendance_percentage_carre      0
# sleep_hours_carre                0
# exercise_frequency_carre         0
# mental_health_rating_carre       0
# gender                           0
# part_time_job                    0
# diet_quality                     0
# parental_education_level         0
# internet_quality                 0
# extracurricular_participation    0
# dtype: int64

# %%
X = df_final
y = df_1.exam_score

# %%
for col in ['gender', 'part_time_job', 'extracurricular_participation',
            'diet_quality', 'parental_education_level', 'internet_quality']:
    print(f"{col} : {df_final[col].unique()}")
# Out:
# gender : ['Female' 'Male' 'Other']
# part_time_job : ['No' 'Yes']
# extracurricular_participation : ['Yes' 'No']
# diet_quality : ['Fair' 'Good' 'Poor']
# parental_education_level : ['Master' 'High School' 'Bachelor']
# internet_quality : ['Average' 'Poor' 'Good']

# %%
# Encodage des variables ordinales
diet_map = {'Poor': 0, 'Fair': 1, 'Good': 2}
X['diet_quality'] = X['diet_quality'].map(diet_map)

education_map = {'High School': 0, 'Bachelor': 1, 'Master': 2}
X['parental_education_level'] = X['parental_education_level'].map(education_map)

internet_map = {'Poor': 0, 'Average': 1, 'Good': 2}
X['internet_quality'] = X['internet_quality'].map(internet_map)

# Encodage des variables nominales
gender_map = {'Female': 0, 'Male': 1, 'Other': 2}
X['gender'] = X['gender'].map(gender_map)

job_map = {'No': 0, 'Yes': 1}
X['part_time_job'] = X['part_time_job'].map(job_map)

extra_map = {'No': 0, 'Yes': 1}
X['extracurricular_participation'] = X['extracurricular_participation'].map(extra_map)

# %%
X.head()
# Out:
#    age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23                  0.0                 1.2            1.1
# 1   20                  6.9                 2.8            2.3
# 2   21                  1.4                 3.1            1.3
# 3   23                  1.0                 3.9            1.0
# 4   19                  5.0                 4.4            0.5
#
#    attendance_percentage  sleep_hours  exercise_frequency  \
# 0                   85.0          8.0                   6
# 1                   97.3          4.6                   6
# 2                   94.8          8.0                   1
# 3                   71.0          9.2                   4
# 4                   90.9          4.9                   3
#
#    mental_health_rating  age_carre  study_hours_per_day_carre  ...  \
# 0                     8        529                       0.00  ...
# 1                     8        400                      47.61  ...
# ...

# %%
# Normalisation
mean = X.mean()
std = X.std()

X_scaled = (X - mean) / std
print(X_scaled.describe().round(2))
# Out:
#            age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.00              1000.00             1000.00        1000.00
# mean     -0.00                -0.00               -0.00          -0.00
# std       1.00                 1.00                1.00           1.00
# min      -1.52                -2.42               -2.14          -1.69
# 25%      -0.76                -0.65               -0.69          -0.76
# 50%      -0.22                -0.03               -0.00          -0.02
# 75%       1.08                 0.65                0.68           0.66
# max       1.52                 3.23                4.00           3.33
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count                1000.00      1000.00             1000.00
# mean                    0.00        -0.00                0.00
# std                     1.00         1.00                1.00
# min                    -2.99        -2.67               -1.50
# ...

# %%
# Conversion en listes Python
X_tab = X_scaled.values.tolist()
y_tab = y.values.tolist()



X_b = X_tab

# %%
# Implémentation de la régression linéaire
def regression_lineaire(X, w, b):
    y_pred = []
    for i in range(len(X)):
        val = 0
        for j in range(len(w)):
            val += w[j] * X[i][j]
        val += b
        y_pred.append(val)
    return y_pred

# %%
# Fonction MSE
def mse(y_attendu, y_pred):
    m = len(y_attendu)
    sum = 0
    for i in range(m):
        sum += (y_attendu[i] - y_pred[i])**2
    return sum / m

# %%
# Dérivées partielles
def derivee_w(X, y_true, w, y_pred):
    m = len(y_true)
    grads = []

    for j in range(len(w)):
        deriv_w = 0
        for i in range(m):
            deriv_w += (y_pred[i] - y_true[i]) * X[i][j]
        grads.append((2/m) * deriv_w)

    return grads

def derivee_b(y_true, y_pred):
    m = len(y_true)
    grad_b = 0

    for i in range(m):
        grad_b += (y_pred[i] - y_true[i])

    return (2/m) * grad_b

# %%
def r2_score(y_true, y_pred):
    y_mean = sum(y_true) / len(y_true)

    ss_total = 0
    ss_res = 0

    for i in range(len(y_true)):
        ss_total += (y_true[i] - y_mean) ** 2
        ss_res += (y_true[i] - y_pred[i]) ** 2

    return 1 - (ss_res / ss_total)

# %%
import random
random.seed(42)
data = list(zip(X_tab, y_tab))
random.shuffle(data)

# %%
split_ratio = 0.8
split_index = int(len(data) * split_ratio)

train_data = data[:split_index]
test_data = data[split_index:]

# %%
X_train = [x for x, y in train_data]
y_train = [y for x, y in train_data]

X_test = [x for x, y in test_data]
y_test = [y for x, y in test_data]

# %%
# Initialiser les poids à 0
w = [0] * len(X_train[0])
b = 0
# Gradient Descent
alpha = 0.01
n_iter = 2000
list_cout = []




for i in range(n_iter):
    y_pred = regression_lineaire(X_train, w, b)

    #  Coût
    cout = mse(y_train, y_pred)
    list_cout.append(cout)

    dw = derivee_w(X_train, y_train, w, y_pred)
    db = derivee_b(y_train, y_pred)

    for j in range(len(w)):
        w[j] -= alpha * dw[j]

    b -= alpha * db

# %%
plt.plot(range(n_iter), list_cout)
plt.xlabel("Itérations")
plt.ylabel("Coût (MSE)")
plt.title("Évolution du coût")
plt.show()

# %%
y_pred_test = regression_lineaire(X_test, w, b)

print("MSE test :", mse(y_test, y_pred_test))
print("R² test :", r2_score(y_test, y_pred_test))
# Out:
# MSE test : 26.487692881403515
# R² test : 0.8975215896130849

# %%
y_pred_train = regression_lineaire(X_train, w, b)

print("MSE² train :", mse(y_train, y_pred_train))
print("R² train :", r2_score(y_train, y_pred_train))
# Out:
# MSE² train : 27.952120358708314
# R² train : 0.9041163338603552

# %%
# Définir les noms des colonnes
colonnes = list(X_train[0].keys()) if isinstance(X_train[0], dict) else list(X_scaled.columns)

importance = []
for i in range(len(w)):
    importance.append((colonnes[i], abs(w[i])))

importance.sort(key=lambda x: x[1], reverse=True)

for col, val in importance:
    print(col, val)
print(f"Biais : {b:.4f}")
# Out:
# study_hours_per_day 15.137884540602995
# mental_health_rating 4.324270783098704
# social_media_hours 3.783310126177723
# netflix_hours 2.413225398756576
# exercise_frequency 2.404049316144687
# sleep_hours 1.5069928271829103
# study_hours_per_day_carre 1.2682946077059156
# mental_health_rating_carre 1.0957351416324508
# sleep_hours_carre 0.9486003540557163
# attendance_percentage_carre 0.8838595859892168
# social_media_hours_carre 0.8065565386235298
# exercise_frequency_carre 0.7020079606659584
# attendance_percentage 0.41142051540318114
# extracurricular_participation 0.22897679228007028
# age 0.1792059600075666
# internet_quality 0.17853265845172175
# age_carre 0.17323640950518815
# parental_education_level 0.13797365300730902
# part_time_job 0.12874967997145687
# netflix_hours_carre 0.07723694196394781
# diet_quality 0.05745793288266494
# gender 0.051348478221466154
# Biais : 69.5129

# %%
# regression avec toutes les variables élevées au carré
X_poly = X.copy()
for col in list(X.columns):
    X_poly[col + '_carre'] = X[col] ** 2

# Normalisation
mean_poly = X_poly.mean()
std_poly = X_poly.std()
X_poly_scaled = (X_poly - mean_poly) / std_poly

# Conversion en liste + ajout biais
# Conversion + biais
X_poly_array = X_poly_scaled.values.tolist()
X_poly_b = []
for row in X_poly_array:
    X_poly_b.append([1] + row)

# Train/Test split polynomial
data_poly = list(zip(X_poly_b, y))
random.seed(42)
random.shuffle(data_poly)

train_poly = data_poly[:split_index]
test_poly = data_poly[split_index:]

X_train_poly = [x for x, y_ in train_poly]
y_train_poly = [y_ for x, y_ in train_poly]
X_test_poly = [x for x, y_ in test_poly]
y_test_poly = [y_ for x, y_ in test_poly]

w_poly = [0] * len(X_train_poly[0])
b_poly = 0
alpha_poly = 0.01
n_iter_poly = 2000
list_cout_poly = []

for i in range(n_iter_poly):
    y_pred_poly = regression_lineaire(X_train_poly, w_poly, b_poly)
    cout = mse(y_train_poly, y_pred_poly)
    list_cout_poly.append(cout)
    dw = derivee_w(X_train_poly, y_train_poly, w_poly, y_pred_poly)
    db = derivee_b(y_train_poly, y_pred_poly)
    for j in range(len(w_poly)):
        w_poly[j] = w_poly[j] - alpha_poly * dw[j]
    b_poly = b_poly - alpha_poly * db

print("Coût initial poly :", list_cout_poly[0])
print("Coût final poly :", list_cout_poly[-1])
print("R² train poly :", r2_score(y_train_poly, regression_lineaire(X_train_poly, w_poly, b_poly)))
print("R² test poly :", r2_score(y_test_poly, regression_lineaire(X_test_poly, w_poly, b_poly)))

# Courbe du coût
plt.plot(range(n_iter_poly), list_cout_poly)
plt.xlabel("Itérations")
plt.ylabel("Coût (MSE)")
plt.title("Évolution du coût - Régression Polynomiale")
plt.show()
# Out:
# Coût initial poly : 5124.412549999993
# Coût final poly : 25.92370751238505
# R² train poly : 0.9110744654000384
# R² test poly : 0.8892743809603805

# %%
print("MSE train poly :", mse(y_train_poly, regression_lineaire(X_train_poly, w_poly, b_poly)))
print("MSE test poly :", mse(y_test_poly, regression_lineaire(X_test_poly, w_poly, b_poly)))
# Out:
# MSE train poly : 25.92367757904145
# MSE test poly : 28.619356800632104

# %% [markdown]
# Le Modèle 1 (carrés des variables quantitatives uniquement) est meilleur car il généralise mieux sur les données test. Ajouter les carrés des variables catégorielles dans le Modèle 2 introduit du bruit, augmente la complexité et cause de l'overfitting sans améliorer les performances réelles du modèle.
